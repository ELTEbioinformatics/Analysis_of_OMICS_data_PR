# %% [markdown]
# # Tasks - Introduction to Bash and the Linux environment
#
# <div class="alert alert-info" style="background-color:rgba(212, 240, 255, 0.5); border-color:rgba(212, 240, 255, 1)">
# Use this notebook as a template to solve the following tasks.
#
# - Use Markdown cells for headings and explanations
# - Use code cells to run bash commands with the `!` prefix or the `%%bash` magic command. **Don't forget to actually run the commands by pressing **Shift+Enter** or **Ctrl+Enter**!**
# - Provide explanations and comments in the code cells by starting them with `#`
# - For screenshot tasks, create a screenshot, upload it to the `practical1` folder and insert the image in the Markdown cell
#
# </div>

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 1
# Connect to your assigned Linux server using SSH. Your instructor will provide:
#
# - Server address
# - Your username
# - Your temporary password
# - Port number (if different from default)
#
# Once connected, **change your password to a permanent password.**
#
# 1. What command did you use to change your password? (Answer in a Markdown cell below.)
#
# 2. After this, run the following commands in a Code cell using the `%%bash` magic command:
#
# ```
# whoami
# hostname
# pwd
# ```
# <br>
#
# **Don't forget to run the cells by pressing Shift+Enter or Ctrl+Enter!**
#
# </div>

# %% [markdown]
# **Your answer for 1/1:**

# %%
# %%bash
# # write your commands here for 1/2

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 2
#
# List all files (including hidden ones) in your home directory with detailed information and human-readable sizes, sorted by modification time.
#
# </div>

# %%
# %%bash
# # write your command here

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 3
#
# Use the `man` command to read about the `ls` command. Write down what the following options do:
#
# - `ls -l`:
# - `ls -r`:
# - `ls -t`:
#
# </div>

# %%
# %%bash
# # write your commands here

# %% [markdown]
# **Your answers:**
#
# - `ls -l`:
# - `ls -r`:
# - `ls -t`:

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 4
#
# Practice navigating the file system:
#
# 1. Use `pwd` to see your current location
# 2. Use `cd` to go to your home directory
# 3. Use `pwd` to confirm you're in your home directory
# 4. Create a test directory structure: `mkdir -p test/sub1/sub2`
# 5. Navigate to `test/sub1/sub2` using a relative path
# 6. Use `pwd` to confirm your location
# 7. Go up two levels using `cd ../..`
# 8. Use `pwd` to confirm you're back in the `test` directory
# 9. Use `cd -` to go back to `sub2` and confirm with `pwd`
# 10. Use `cd ~` to return to your home directory and confirm with `pwd`
#
# </div>

# %%
# %%bash
# # write your commands here

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 5
#
# Create a directory structure for a genomics project with the following layout:
#
# ```
# genomics_project/
# ├── data/
# │   ├── raw/
# │   └── processed/
# ├── scripts/
# ├── results/
# └── documentation/
# ```
#
# 1. Use a single command to create all directories at once.
# 2. Use another command to check if the directories were created correctly.
#
# </div>

# %%
# %%bash
# # write your command here for 5/1
#
#
# # write your command here for 5/2

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 6
#
# Practice with file operations. Use a separate code cell for each of these commands and issue an `ls` command after each step to verify the results.
#
# 1. Create a directory called `dir_practice`
# 2. Create three empty files within it: `test1.txt`, `test2.txt`, `test3.txt`
# 3. Copy `test1.txt` to `test1_backup.txt`
# 4. Rename `test2.txt` to `renamed.txt` using `mv`
# 5. Create a subdirectory called `archive`
# 6. Copy `test3.txt` to the `archive` directory (verify with `ls` on the `archive` directory AND the `dir_practice` directory)
# 7. Move `test1_backup.txt` to the `archive` directory (verify with `ls` on the `archive` directory AND the `dir_practice` directory)
# 8. Remove `renamed.txt` from the `dir_practice` directory
# 9. Remove the entire `dir_practice` directory. Write down which command you used for this and why.
#
# </div>

# %%
# %%bash
# # write your commands here for 6/1

# %%
# %%bash
# # write your commands here for 6/2

# %%
# %%bash
# # write your commands here for 6/3

# %%
# %%bash
# # write your commands here for 6/4

# %%
# %%bash
# # write your commands here for 6/5

# %%
# %%bash
# # write your commands here for 6/6

# %%
# %%bash
# # write your commands here for 6/7

# %%
# %%bash
# # write your commands here for 6/8

# %%
# %%bash
# # write your commands here for 6/9

# %% [markdown]
# **Answer for 6/9:**

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 7
#
# 1. In your `genomics_project/data/raw/` directory, create an empty file called `large_dataset.txt` using `touch`
# 2. Go to the `genomics_project/data/processed/` directory
# 3. Create a symbolic link to the raw data file and call it `raw_link.txt`
# 4. Use `ls -l` in the processed directory to verify the link was created
# 5. Write down the file size of the link
#
# </div>

# %%
# %%bash
# # write your commands here

# %% [markdown]
# **Link file size (7/5):**

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 8
#
# 1. Download a sample dataset from the following URL and save it to your `genomics_project/data/raw/` directory with the filename `chr22_reference.fa.gz`:
#
# `https://ftp.ensembl.org/pub/release-110/fasta/homo_sapiens/dna/Homo_sapiens.GRCh38.dna.chromosome.22.fa.gz`
#
# 2. Verify with `ls`.
#
# </div>

# %%
# %%bash
# # write your command here for 8/1

# %%
# %%bash
# # write your command here for 8/2

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 9
#
# Practice with file permissions. **Run these commands in a Terminal, not in this Jupyter notebook.** Only write down your observations here.
#
# 1. Create a file called `important_data.txt` using `touch`
# 2. Check its permissions with `ls -l`
# 3. Remove write permissions: `chmod u-w important_data.txt`
# 4. Try to modify the file: `echo "new data" > important_data.txt` - what happens?
# 5. Try to delete it with `rm important_data.txt`
#    - What does `rm` ask you?
#    - What happens if you press Enter without typing anything?
#    - What happens if you type 'y'?
#
# Write down what you observed.
#
# </div>

# %% [markdown]
# **Your observations for 9/4:**

# %% [markdown]
# **Your observations for 9/5:**
#
# - What does `rm` ask you?
# - What happens if you press Enter without typing anything?
# - What happens if you type 'y'?

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 10
#
# 1. Decompress the file you downloaded previously (`chr22_reference.fa.gz`), but keep the original compressed version.
# 2. Compare the file size of the decompressed file with the original compressed file.
#
# </div>

# %%
# %%bash
# # write your commands here for 10/1

# %%
# %%bash
# # write your commands here for 10/2

# %% [markdown]
# **File sizes of the original and the decompressed files:**

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 11
#
# Practice with archives:
#
# 1. Create a directory called `test_archive` with a few files inside (use `touch` to create files)
# 2. Create a compressed archive called `test.tar.gz` containing the directory
# 3. List the contents of the archive without extracting
# 4. Remove the original directory
# 5. Extract the archive to restore the directory
#
# </div>

# %%
# %%bash
# # write your commands here for 11/1

# %%
# %%bash
# # write your commands here for 11/2

# %%
# %%bash
# # write your commands here for 11/3

# %%
# %%bash
# # write your commands here for 11/4

# %%
# %%bash
# # write your commands here for 11/5

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 12
#
# View the first 5 lines of your decompressed reference genome file (`chr22_reference.fa`) to see the FASTA header format.
#
# </div>

# %%
# %%bash
# # write your command here

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 13
#
# **Use a Terminal for this task and write all commands there and not in this notebook.** (You can use e.g. "File > New > Terminal".)
#
# Open a large file (like your reference genome) with `less`. Practice navigating:
#
# 1. Jump to the end with `G`
# 2. Jump back to the beginning with `g`
# 3. Search for "NNNN" using `/NNNN`
# 4. Quit with `q`
#
# **Why is `less` better than `cat` for large files?**
#
# </div>

# %% [markdown]
# **Your answer:**

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 14
#
# How many lines are there in your reference genome file?
#
# </div>

# %%
# %%bash
# # write your command here

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 15
#
# Use the `grep` command to answer the following questions about your reference genome file:
#
# 1. Find all sequence headers (lines starting with `>`).
#
# 2. Find all lines that contain the pattern "NNNNN" (stretches of at least 5 unknown nucleotides) and show the *first three* matches. Display line numbers, so that you can check that the correct lines have been found.
#
# 3. How many lines are there in the file that are not sequence headers (lines NOT starting with `>`)? Do not print these lines, just their number.
#
# </div>

# %%
# %%bash
# # Command for 15/1

# %%
# %%bash
# # Command for 15/2

# %%
# %%bash
# # Command for 15/3

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 16
#
# Find out what version of `grep` and `wget` are installed on your system.
#
# </div>

# %%
# %%bash
# # write your commands here

# %% [markdown]
# **Version of `grep`:**
#
# **Version of `wget`:**

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 17
#
# Practice with echo and date:
#
# 1. Use `echo -e` to create a file called `experiments.txt` with these lines (use tabs `\t` between columns and `\n` between lines):
#    ```
#    Experiment1    2024-01-15    Success
#    Experiment2    2024-01-16    Failed
#    Experiment3    2024-01-17    Success
#    ```
#
# 2. Create a log file with the current date in its filename using the date command
#
# 3. Write the current date and time to that log file using echo and date together. Use `.` to separate year, month and day, and `:` to separate hours, minutes and seconds.
#
# </div>

# %%
# %%bash
# # write your command here for 17/1

# %%
# %%bash
# # write your command here for 17/2

# %%
# %%bash
# # write your command here for 17/3

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 18
#
# Create variables for your project directory and data directory, then use them to list the contents of your raw data folder.
#
# </div>

# %%
# %%bash
# # Set your variables here
#
#
# # Use them to list contents

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 19
#
# Using pipes, extract the first sequence line (not the header) from a FASTA file.
#
# **Hint:** FASTA files have headers starting with `>`, followed by sequence lines. You want to skip the first line (header) and show one sequence line.
#
# </div>

# %%
# %%bash
# # write your piped command here

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 20
#
# Create three small text files with sample names and combine them into one file. Each file should have 3-4 sample names (one per line).
#
# </div>

# %%
# %%bash
# # Create the files
# echo -e "sample1\nsample2\nsample3" > batch1.txt
# echo -e "sample4\nsample5\nsample6" > batch2.txt
# echo -e "sample7\nsample8\nsample9" > batch3.txt
#
# # Combine them (write your command)

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 21
#
# Practice with text manipulation:
#
# 1. Create a file called `data.txt` with the following tab-delimited content:
#    ```
#    chr1    100    GeneA
#    chr1    200    GeneB
#    chr2    150    GeneC
#    chr2    300    GeneA
#    chr1    400    GeneB
#    ```
#
# 2. Extract only the chromosome column (column 1).
#
# 3. Count how many times each chromosome appears (use `sort` and `uniq -c`).
#
# 4. Extract the gene names (column 3), sort them, and show only unique gene names (but not their count).
#
# 5. Create two files: `chromosomes.txt` (column 1) and `positions.txt` (column 2), then use paste to recreate the first two columns.
#
# </div>

# %%
# %%bash
# # 21/1. Create the data file
# echo -e "chr1\t100\tGeneA\nchr1\t200\tGeneB\nchr2\t150\tGeneC\nchr2\t300\tGeneA\nchr1\t400\tGeneB" > data.txt
# cat data.txt

# %%
# %%bash
# # 21/2. Extract chromosome column

# %%
# %%bash
# # 21/3. Count chromosome occurrences

# %%
# %%bash
# # 21/4. Extract and show unique gene names

# %%
# %%bash
# # 21/5. Create separate files and paste them together

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 22
#
# Create a loop that:
#
# 1. Processes all `.txt` files in your current directory.
# 2. For each file, prints the filename and the number of lines it contains.
# 3. Saves this information to a file called `file_summary.txt`
#
# </div>

# %%
# %%bash
# # write your loop here

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 23
#
# Create a tab-delimited file with data from at least 3 different chromosomes (chr1, chr2, chr3), then split it into separate files for each chromosome. Make sure that the resulting files contain lines in an ascending order based on the position column. Use `|` for piping commands.
#
# </div>

# %%
# %%bash
# # Create your data file
# echo -e "chr1\t100\tGeneA\nchr1\t200\tGeneB\nchr2\t150\tGeneC\nchr3\t300\tGeneE\nchr2\t50\tGeneA\nchr1\t400\tGeneB\nchr3\t100\tGeneD\n" > data_multi_chroms.txt
# cat data_multi_chroms.txt

# %%
# %%bash
# # Split the file to get sorted files for each chromosome. Use a single line of command to achieve this.

# %% [markdown]
# ---
#
# <div class="alert alert-warning" style="background-color:rgba(255, 227, 194, 0.5); border-color:rgba(255, 227, 194, 1); color:rgba(0, 0, 0, 0.8)">
#
# ## Task 24
#
# Practice launching graphical applications:
#
# 1. Connect to your server with X11 forwarding: `ssh -X -p 2227 username@rstudio.dlab.elte.hu`
# 2. Verify X11 is working: `echo $DISPLAY`
# 3. Launch these applications one by one:
#    - `firefox`
#    - `igv &`
#    - `jupyter notebook` (using port forwarding method if preferred)
# 4. Take a screenshot showing the graphical application window running
# 5. Submit your screenshot as proof of successful X11 forwarding
#
# **Important:** The screenshot should show:
# - The application window (Firefox, IGV, and/or Jupyter)
# - Proof it's running from the remote server (e.g., terminal in background showing the ssh session)
#
# </div>

# %% [markdown]
# **Insert your screenshots here:**
#
# ### Firefox
#
# <!-- Upload your screenshot to the practical1 folder and use markdown to insert it:
# ![X11 Forwarding Screenshot](screenshot_name.png)
# -->
#
# ### IGV
#
# ### Jupyter notebook

# %% [markdown]
# ---
#
# ## Congratulations!
#
# You've completed all the tasks for the Introduction to Bash and Linux practical.
#
# **Before submitting:**
# 1. Make sure all code cells have been run (Shift+Enter)
# 2. Check that all your answers are filled in
# 3. Save this notebook (Ctrl+S or Cmd+S)
# 4. Make sure this notebook is in your `practical1` folder
# 5. Name it: `firstname_lastname_practical1.ipynb`
#
# **To download your notebook:**
# - File → Download as → Notebook (.ipynb)
